# %%
import requests

# %%
s = requests.Session()

# %%
res1 = s.get("http://www.pizzahut.com.tw/place/?c=c")

# %%
s.cookies.get_dict()
# Out:
# {'PHPSESSID': '39tviftlou4svmm2u2i16rpvo4', 'pida': 'tai_map'}

# %%
res2 = s.get("http://www.pizzahut.com.tw/place/?parent_id=cdsp&a=a")

# %%
s.cookies.get_dict()
# Out:
# {'GAtracking': 'dced392a81eca2b00cfac61ee15d44f063cf2939',
#  'PHPSESSID': '39tviftlou4svmm2u2i16rpvo4',
#  'YAtracking': '11325e3b5f8e8091d5f292b9dd00b18feb6863bd',
#  'pida': 'cdsp'}

# %%
res = s.get("http://www.pizzahut.com.tw/place/show_map2.php?ccity=%E5%8F%B0%E5%8C%97%E5%B8%82&czone=0")

# %%
res.text
# Out:
# u'<table width=\'100%\' border=\'0\' cellspacing=\'0\' cellpadding=\'0\'><tr><td class="f1" id="tdcity_24">\xe5\x8f\xb0\xe5\x8c\x97\xe5\xb8\x82</td><td class="f2">\xe5\xa3\xab\xe6\x9e\x97\xe4\xb8\xad\xe6\xad\xa3\xe5\xba\x97</td><td class="f3"><a href="javascript:show_address_map(\'\xe5\xa3\xab\xe6\x9e\x97\xe4\xb8\xad\xe6\xad\xa3\xe5\xba\x97\',\'24\')">\xe5\x8f\xb0\xe5\x8c\x97\xe5\xb8\x82\xe5\xa3\xab\xe6\x9e\x97\xe5\x8d\x80\xe4\xb8\xad\xe6\xad\xa3\xe8\xb7\xaf241\xe8\x99\x9f</a></td><td class="f5"><a href="javascript:show_address_map(\'\xe5\xa3\xab\xe6\x9e\x97\xe4\xb8\xad\xe6\xad\xa3\xe5\xba\x97\',\'24\')"><span style=\'font-size:90%\'>\xe5\x9c\xb0\xe5\x9c\x96</span><img src="/ml_images/gmap-mark.gif" alt="" /></a></td><td class="f4">02-2883-9850</td><td class="f5_1"><img src="/ml_images/icon-del.png" alt="" /></td><td class="f5_2"><img src="/ml_images/icon-out.png" alt="" /></td><td class="f6"><a href="javascript:movetoorders(\'\xe5\x8f\xb0\xe5\x8c\x97\xe5\xb8\x82\',\'\xe5\xa3\xab\xe6
# ...

# %%
s.cookies.update({"jscity":"%E5%8F%B0%E5%8C%97%E5%B8%82", "jsarea":"%E5%A4%A7%E5%AE%89%E5%8D%80"})

# %%
s.cookies.get_dict()
# Out:
# {'PHPSESSID': 'to9iu3v7r1a7apkkj47t8e7m46',
#  'jsarea': '%E5%A4%A7%E5%AE%89%E5%8D%80',
#  'jscity': '%E5%8F%B0%E5%8C%97%E5%B8%82'}
